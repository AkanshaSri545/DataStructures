# %% [markdown]
# 1)  What is Object-Oriented Programming (OOP)?
# Object-Oriented Programming (OOP) is a programming paradigm centered around the concept of "objects," which are instances of classes. These objects bundle both data (attributes) and behavior (methods) into a single unit, allowing developers to model real-world entities in a more intuitive and organized way. OOP is based on four main principles: encapsulation, which hides internal object details and exposes only what's necessary; inheritance, which allows one class to inherit properties and methods from another, promoting code reuse; polymorphism, which enables different classes to be treated as the same type through a shared interface while exhibiting different behaviors; and abstraction, which hides complex implementation details and shows only the relevant features. This approach helps in building modular, maintainable, and scalable software systems, making it easier to manage complexity in large codebases.

# %% [markdown]
# 2) What is a class in OOP?
# In Object-Oriented Programming (OOP), a class is a blueprint or template for creating objects. It defines a set of attributes (data) and methods (functions) that the objects created from the class will have. Think of a class as a mold, and objects as the products made from that mold. For example, a class called Car might include attributes like brand, model, and color, as well as methods like start() or drive(). While the class itself doesn't hold actual data, it provides the structure, and each object or instance of that class holds specific values for those attributes. Classes help organize code, promote reusability, and support the core principles of OOP such as encapsulation and inheritance.

# %% [markdown]
# 3)  What is an object in OOP?
#
# In Object-Oriented Programming (OOP), an object is an instance of a class and represents a real-world entity that contains both data and behavior. While a class is like a blueprint, an object is the actual implementation of that blueprint, with its own unique values assigned to the attributes defined by the class. For example, if Car is a class, then myCar = Car("Toyota", "Corolla") is an object representing a specific car with the brand "Toyota" and model "Corolla." Objects allow programs to model real-world elements more naturally by combining state (attributes) and functionality (methods) into a single unit. This makes the code more modular, reusable, and easier to understand and maintain.

# %% [markdown]
# 4) What is the difference between abstraction and encapsulation?
#
# The difference between abstraction and encapsulation in Object-Oriented Programming lies in their purpose and implementation. Abstraction is the process of hiding complex implementation details and exposing only the essential features of an object. It helps reduce complexity by allowing the user to interact with an object through a simple interface without needing to understand its inner workings. For example, when you use a drive() method in a Car class, you don’t need to know how the engine or transmission works internally. On the other hand, encapsulation is about hiding the internal data of an object and restricting direct access to it. This is done by making variables private and providing controlled access through public getter and setter methods. Encapsulation helps protect the integrity of the data and ensures that it is accessed or modified only in intended ways. While both abstraction and encapsulation deal with hiding aspects of a system, abstraction hides complexity, and encapsulation hides data.

# %% [markdown]
# 5) What are dunder methods in Python?
#
# Dunder methods in Python, also known as magic methods or special methods, are predefined methods that have double underscores (short for “dunder”) at the beginning and end of their names, such as __init__, __str__, __len__, and __add__. These methods allow you to define or customize the behavior of Python objects for built-in operations. For example, __init__ is used as a constructor to initialize an object’s attributes when it is created, while __str__ defines how an object is represented as a string when printed. Dunder methods enable operator overloading, meaning you can define how operators like +, -, or == behave for your custom classes using methods like __add__, __sub__, or __eq__. While you typically don’t call dunder methods directly, Python automatically invokes them in appropriate situations, making your objects behave more like built-in types.

# %% [markdown]
# 6) Explain the concept of inheritance in OOP.
# Inheritance in Object-Oriented Programming (OOP) is a fundamental concept that allows one class (called the child or subclass) to acquire the properties and behaviors (attributes and methods) of another class (called the parent or superclass). This means that the child class can use the code defined in the parent class without rewriting it, which promotes code reusability, modularity, and maintainability.
#
# Inheritance also supports the concept of hierarchies, where general classes can be extended into more specific ones. For example, a Vehicle class may have common properties like speed and fuel, and child classes like Car and Bike can inherit these properties while also defining their own unique features.
#
# In many languages like Python, Java, or C++, a child class can override methods from the parent class to provide specific behavior. Inheritance also lays the foundation for polymorphism, where different classes can define the same method in different ways.
#
# Overall, inheritance helps in building a logical and efficient class structure, reducing redundancy, and making complex programs easier to manage and extend.

# %% [markdown]
# 7) What is polymorphism in OOP?
#
# Polymorphism in Object-Oriented Programming (OOP) is the ability of different objects to respond to the same method or function in different ways. The word "polymorphism" comes from Greek, meaning "many forms." In programming, this means that a single interface or method name can represent different underlying forms (data types or class implementations).
#
# There are two main types of polymorphism:
#
# a) Compile-time (Static) Polymorphism – Achieved through method overloading or operator overloading, where multiple methods have the same name but differ in the number or type of parameters. (More common in languages like Java and C++.)
#
# b) Runtime (Dynamic) Polymorphism – Achieved through method overriding, where a subclass provides a specific implementation of a method that is already defined in its parent class.
#
# For example, suppose you have a parent class Animal with a method speak(), and subclasses like Dog and Cat each override speak() with their own version. When you call speak() on an Animal object, Python determines at runtime which version to execute based on the actual object type.
#
# Polymorphism makes code more flexible and extensible, allowing you to write generic code that can work with objects of different classes in a unified way.

# %% [markdown]
# 8) How is encapsulation achieved in Python?
#
# Encapsulation in Python is achieved through the use of private and protected access modifiers, which help restrict direct access to an object's internal data. In Python, attributes and methods are typically public by default, meaning they can be accessed from outside the class. However, by convention, a single underscore (_) is used to indicate that an attribute or method is protected, suggesting it is intended for internal use or for subclass access. A double underscore (__) is used to mark attributes or methods as private, which triggers name mangling in Python, making it harder to access them directly from outside the class. While Python does not enforce strict access control like some other programming languages, these naming conventions help communicate the intended level of access.
#
# To further implement encapsulation, Python provides getter and setter methods, which are used to access or modify private attributes in a controlled manner. These methods allow for validation, logging, or additional logic when data is retrieved or set. For example, a class may use a setter method to check if a given value is valid before assigning it to a private variable, ensuring that the object's internal state remains consistent and secure. Through encapsulation, Python encourages better data security, reduces the risk of accidental changes, and promotes cleaner, more modular code by hiding internal details and exposing only necessary interfaces.

# %% [markdown]
# 9) What is a constructor in Python?
#
# ChatGPT said:
# A constructor in Python is a special method used to initialize objects when they are created. It is defined by the __init__ method, which is automatically called when a new instance of a class is instantiated. The primary role of a constructor is to set up the initial state of an object by assigning values to its attributes, often based on parameters passed during object creation.
#
# In Python, the __init__ method allows you to define how an object should be initialized with certain values when it is created. While the constructor doesn't return any value (it always returns None), it can accept arguments that are used to initialize the object's properties.

# %% [markdown]
# 10) What are class and static methods in Python?
#
# In Python, class methods are methods that are bound to the class and not the instance of the class. They are defined using the @classmethod decorator and take cls as their first parameter, which refers to the class itself, not an instance. Class methods can access or modify class-level attributes, but they cannot access instance-level attributes unless explicitly passed an instance. They are typically used for factory methods, which create instances of the class, or for methods that affect the class as a whole, rather than individual objects.
#
# On the other hand, static methods are methods that do not take either self (for instance methods) or cls (for class methods) as their first parameter. They are defined using the @staticmethod decorator. Static methods are used for functions that are related to the class but do not need access to class or instance-specific data. They behave like regular functions, except that they reside within the class's namespace. Static methods are useful for utility functions or when a method performs a task that is relevant to the class but doesn’t need access to any class or instance attributes.

# %% [markdown]
# 11) What is method overloading in Python?
#
# Method overloading in Python refers to the ability to define multiple methods with the same name but with different parameters (number or type). However, Python does not support traditional method overloading as seen in languages like Java or C++. In Python, the most recent method definition overrides any previous definitions with the same name, meaning that only one version of a method can exist at a time within a class.
#
# To achieve method overloading-like behavior in Python, developers typically use default arguments, variable-length arguments (such as *args and **kwargs), or conditional statements within a single method. This allows the method to handle different numbers of arguments or different types of data passed to it. While Python doesn't natively support multiple methods with the same name, these techniques enable similar functionality, giving flexibility to method behavior based on the input

# %% [markdown]
# 12) What is method overriding in OOP?
#
# Method overriding in Object-Oriented Programming (OOP) occurs when a subclass provides a specific implementation of a method that is already defined in its superclass. The method in the subclass must have the same name, same parameters, and same return type as the one in the superclass. Overriding allows the subclass to modify or extend the behavior of the inherited method to suit its own needs, enabling more specialized functionality without changing the superclass code.
#
# When a method is overridden in a subclass, Python will call the subclass’s version of the method rather than the one in the parent class when the method is invoked on an instance of the subclass. This allows for dynamic behavior based on the specific subclass type, making it a key aspect of polymorphism. Method overriding is commonly used to provide specific behavior for different subclasses, ensuring that the objects exhibit the correct functionality.

# %% [markdown]
# 13) What is a property decorator in Python?
#
# The property decorator in Python is used to define methods that act like attributes. This allows you to define a method in a class that can be accessed like an attribute, without needing to call it explicitly as a method. The property decorator makes it easier to control the access to an attribute, providing a way to define getter methods, and optionally, setter and deleter methods, all while maintaining the simplicity of attribute-like access.
#
# The main use of the property decorator is to encapsulate internal attributes and control how they are accessed or modified, adding logic to the getter or setter operations while keeping the external interface simple. When a method is decorated with property, it allows you to define logic that will execute when the value is retrieved or set, without requiring the caller to explicitly call a method.

# %% [markdown]
# 14) Why is polymorphism important in OOP?
#
# Polymorphism is important in Object-Oriented Programming (OOP) because it allows for more flexible and reusable code by enabling objects of different classes to be treated as objects of a common superclass, especially when they share a common interface. It enables a unified approach to handling objects of different types, which is crucial for creating scalable, maintainable, and extensible systems.
#
# Here are some reasons why polymorphism is important:
#
# 1. Code Reusability and Flexibility:
# Polymorphism allows you to write generic code that can work with objects of various types, as long as they implement the required methods. This promotes code reusability and flexibility, reducing the need for duplicate code. For example, a function that accepts objects of different classes can be written once and then used across multiple types, as long as they share a common behavior.
#
# 2. Simplifies Code Maintenance and Extensibility:
# Since polymorphism allows different classes to have different implementations of the same method, you can extend a program without modifying existing code. You can simply add new subclasses with their own implementations. This leads to easier maintenance and greater flexibility in making future enhancements.
#
# 3. Encourages Loose Coupling:
# Polymorphism encourages loose coupling between components of the system. When a class uses polymorphism, it doesn't need to know the exact type of the object it is working with, just that it follows a certain interface. This decouples the code that uses the object from the details of the class, making the code easier to modify and test.
#
# 4. Supports Runtime Decision-Making:
# With polymorphism, decisions about which method to call are made at runtime. This is particularly useful in situations where the type of object is not known until execution, such as in design patterns like factory patterns, where the appropriate class can be instantiated based on conditions or configuration at runtime.

# %% [markdown]
# 15) What is an abstract class in Python?
#
# An abstract class in Python is a class that cannot be instantiated directly and is meant to be subclassed by other classes. It is used to define a common interface or blueprint for a group of related classes. Abstract classes contain abstract methods, which are methods that are declared but have no implementation in the abstract class itself. Subclasses that inherit from an abstract class must provide implementations for these abstract methods.
#
# In Python, abstract classes are defined using the abc (Abstract Base Class) module, and you use the abstract method decorator to mark methods as abstract. This helps ensure that any subclass of the abstract class implements these abstract methods, providing a consistent interface across different subclasses.

# %% [markdown]
# 16) What are the advantages of OOP?
#
# Object-Oriented Programming (OOP) offers several advantages that make it a powerful and widely used programming paradigm. Here are the key benefits:
#
# 1. Modularity and Reusability:
# OOP encourages modular code by organizing data and behavior into objects (classes). Once a class is defined, it can be reused across different programs or projects without needing to be rewritten. This reduces redundancy and enhances code maintainability. The concept of inheritance allows classes to be reused and extended, promoting reusability.
#
# 2. Encapsulation:
# OOP supports encapsulation, which means the internal state of an object is hidden from the outside world, and access is controlled through well-defined methods (getters and setters). This helps protect the integrity of data by preventing direct modification and reduces the risk of unintended interactions, thus making the code more secure and easier to maintain.
#
# 3. Abstraction:
# OOP allows abstraction, which simplifies complex systems by providing a high-level view of the objects and hiding unnecessary implementation details. Developers can interact with objects based on their interfaces rather than their internal workings, making the code easier to understand and work with.
#
# 4. Flexibility and Maintainability:
# OOP promotes better code organization, which leads to easier maintenance and updates. For example, when changes are needed, they can often be made within a single class without affecting the entire system. The inheritance mechanism allows for changes to propagate across subclasses, reducing the amount of work required when modifying a system.
#
# 5. Inheritance and Extensibility:
# OOP supports inheritance, which allows one class to inherit the properties and methods of another. This promotes the extensibility of programs, as new functionality can be added by creating new classes that extend existing ones. This leads to less code duplication and greater flexibility in enhancing or modifying behavior without altering existing code.
#
# 6. Polymorphism:
# Polymorphism in OOP allows objects of different types to be treated as objects of a common superclass. This provides a way to write more flexible and generic code that can work with different types of objects, making the code more adaptable and reusable across various contexts. Polymorphism also aids in implementing patterns like strategy or command patterns, enhancing code versatility.
#
# 7. Real-World Modeling:
# OOP is well-suited for modeling real-world problems, as it allows developers to represent entities as objects with both state (attributes) and behavior (methods). This makes it easier to simulate complex systems and maintain a close relationship between the software model and real-world scenarios.
#
# 8. Improved Collaboration:
# OOP encourages modular design, which makes it easier for teams of developers to work on different parts of the codebase simultaneously. Classes and objects are independent units, so different team members can work on different objects or modules without interfering with each other's work.

# %% [markdown]
# 17) What is the difference between a class variable and an instance variable?
#
# A class variable is a variable that is shared by all instances of a class. It is defined within the class but outside any instance methods, and it holds the same value for every instance of the class. Class variables are typically used for values that should be common to all instances, such as constants or settings that are the same across all objects of the class. To access or modify a class variable, it can be done through either the class name or an instance, but changes made to a class variable will reflect across all instances of that class.
#
# An instance variable, on the other hand, is a variable that is specific to each instance of a class. It is typically defined inside the __init__ constructor method, using the self keyword to ensure that each instance has its own copy of the variable. Instance variables are used to store data that can differ between instances, such as the attributes of a person (e.g., name, age) or a car (e.g., make, model). Modifying an instance variable will only affect the specific instance in which it was changed, leaving other instances unaffected. Therefore, class variables provide shared data, while instance variables hold instance-specific data.

# %% [markdown]
# 18) What is multiple inheritance in Python?
#
# Multiple inheritance in Python is a feature that allows a class to inherit attributes and methods from more than one parent class. This means that a single class can have multiple base classes, and it can access the attributes and methods of all of them. Multiple inheritance enables greater flexibility in combining functionalities from different classes, which is particularly useful in complex systems where a class may need to inherit behavior from more than one source.
#
# However, while multiple inheritance can be powerful, it can also lead to ambiguity if two parent classes define methods with the same name or conflicting behaviors. Python handles this using the Method Resolution Order (MRO), which defines the order in which base classes are searched when calling a method or accessing an attribute. The MRO ensures that Python resolves method conflicts in a consistent way, using the C3 linearization algorithm.

# %% [markdown]
# 19) Explain the purpose of ‘’__str__’ and ‘__repr__’ ‘ methods in Python.
#
# 1. __str__ Method:
# The __str__ method is used to define the "informal" or user-friendly string representation of an object. It is called when you use the str() function or when an object is printed using the print() function. The goal of __str__ is to provide a readable, human-friendly string that describes the object in a way that is easy to understand.
#
# If __str__ is not defined, Python will fall back to using the __repr__ method (if defined), or else it will return a generic representation of the object, such as its memory address.
#
# 2. __repr__ Method:
# The __repr__ method is used to define the "official" string representation of an object. Its goal is to provide a string that could, in theory, be used to recreate the object. It is intended to be unambiguous and more technical, often useful for debugging or logging. If you type an object in the interpreter or use the repr() function, the __repr__ method is called.
#
# If __str__ is not defined, Python will use __repr__ as a fallback. However, the reverse is not true: __repr__ is generally expected to be more detailed and formal, often providing a string that includes the class name and attributes.

# %% [markdown]
# 20) What is the significance of the ‘super()’ function in Python?
#
# The super() function in Python is used to call methods from a parent class in a subclass, allowing for method overriding and inheritance to work more effectively. It provides a way to invoke the parent class's version of a method, ensuring that the subclass can extend or modify the behavior of inherited methods without completely overriding them. This is particularly useful when working with multiple inheritance, as super() follows the Method Resolution Order (MRO) to determine which parent class method to call, avoiding method conflicts. It allows for cleaner, more maintainable code by enabling subclasses to reuse and extend the functionality of their parent classes while still adding their own unique behavior. In essence, super() is essential for making code more modular, extensible, and easier to maintain in object-oriented systems.

# %% [markdown]
# 21) What is the significance of the __del__ method in Python?
#
# The __del__ method in Python is a special method that is called when an object is about to be destroyed or garbage collected. It is used to define cleanup operations for an object, such as releasing external resources (e.g., closing files, network connections, or database connections) that the object might have acquired during its lifetime. While Python's garbage collector automatically handles memory management, the __del__ method can be used to ensure that any necessary finalization occurs before the object is removed from memory.
#
# However, the use of __del__ should be approached with caution, as its behavior can be unpredictable, especially when working with circular references. It is not guaranteed to be called immediately after an object goes out of scope, and in certain cases, it may not be called at all if there are still references to the object in the program. This makes __del__ less reliable for some types of resource management. In many cases, it is recommended to use context managers (with statements) or explicit resource management methods to handle cleanup, rather than relying solely on __del__.

# %% [markdown]
# 22) What is the difference between @staticmethod and @classmethod in Python?
#
# The @staticmethod and @classmethod decorators in Python are both used to define methods that are not bound to instance objects, but they serve different purposes and have distinct behaviors. A @staticmethod is a method that does not take an implicit first argument (such as self or cls). It is a regular function that belongs to the class's namespace but does not interact with the class or its instances. This means a static method cannot access or modify class attributes or instance attributes. Static methods are often used when the method needs to perform an operation that doesn't require access to the object's state or class state but is still logically related to the class.
#
# On the other hand, a @classmethod method takes the class itself as its first argument (usually named cls), which allows it to access and modify class-level attributes. A class method is used when you need to operate on or modify the class itself rather than individual instances. Class methods are commonly used for factory methods, which are used to create instances of the class in different ways, or when a method needs to work with class attributes instead of instance-specific data. Thus, while both @staticmethod and @classmethod don't operate on instance data, the key difference is that @classmethod has access to the class itself, whereas @staticmethod does not.

# %% [markdown]
# 23) How does polymorphism work in Python with inheritance?
#
# In Python, polymorphism works with inheritance by allowing objects of different classes to be treated as objects of a common superclass while still calling the correct method for the object's specific class. This ability is fundamental to OOP and enables one interface to work with different data types. Polymorphism ensures that the correct method is invoked based on the actual object type (not the reference type), even when the method is called on a parent class reference or variable.
#
# When a subclass inherits from a superclass, it can override or extend the behavior of the superclass's methods. This means that you can call the same method name on objects of different classes, but the behavior (implementation) of the method will differ depending on the type of object (subclass). Python uses dynamic method resolution to determine which method to call, based on the object type at runtime.

# %% [markdown]
# 24) What is method chaining in Python OOP?
#
# Method chaining in Python OOP refers to the practice of calling multiple methods on the same object in a single line, where each method returns the object itself (or another object that supports further method calls). This allows you to chain method calls together, making the code more concise and readable. The key to method chaining is that each method must return self (the instance of the class) or another object, allowing further methods to be invoked on the result of the previous method call.
#
# Method chaining is often used when you want to perform a sequence of operations on an object without needing to write the object multiple times. It is commonly seen in fluent interfaces, where the flow of method calls feels natural and intuitive.

# %% [markdown]
# 25) What is the purpose of the __call__ method in Python?
#
# he __call__ method in Python is a special method that allows an instance of a class to be called as if it were a function. By defining the __call__ method in a class, you enable instances of that class to behave like callable objects. When an instance of the class is called, Python internally invokes the __call__ method, allowing you to define custom behavior for function-like usage of an object.
#
# This method is particularly useful when you want to encapsulate a certain operation or functionality within an object and make it behave like a function or callable. It is often used in scenarios like decorators, callback functions, and situations where you want objects to have flexible behavior based on how they are invoked.

# %%
#1  Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".


class Animal:
    def speak(self):
        print("Animal makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

animal = Animal()
dog = Dog()

animal.speak()
dog.speak()
# Out:
# Animal makes a sound
# Bark!

# %%
#2 Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

from abc import ABC, abstractmethod
import math

class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * self.radius ** 2

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width
circle = Circle(5)
rectangle = Rectangle(4, 6)

print(f"Area of the Circle: {circle.area()}")
print(f"Area of the Rectangle: {rectangle.area()}")
# Out:
# Area of the Circle: 78.53981633974483
# Area of the Rectangle: 24

# %%
#3 Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car  and further derive a class ElectricCar that adds a battery attribute.

# Parent class: Vehicle
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def display_info(self):
        print(f"Vehicle Type: {self.vehicle_type}")

# Child class: Car (inherits from Vehicle)
class Car(Vehicle):
    def __init__(self, vehicle_type, model):
        super().__init__(vehicle_type)  # Initialize the parent class
        self.model = model

    def display_info(self):
        super().display_info()  # Call the parent class method
        print(f"Car Model: {self.model}")

# Grandchild class: ElectricCar (inherits from Car)
class ElectricCar(Car):
    def __init__(self, vehicle_type, model, battery_capacity):
        super().__init__(vehicle_type, model)  # Initialize the parent class (Car)
        self.battery_capacity = battery_capacity

    def display_info(self):
        super().display_info()  # Call the parent class method
        print(f"Battery Capacity: {self.battery_capacity} kWh")

# Creating an instance of ElectricCar
electric_car = ElectricCar("Electric", "Tesla Model S", 100)

# Calling the display_info method
electric_car.display_info()
# Out:
# Vehicle Type: Electric
# Car Model: Tesla Model S
# Battery Capacity: 100 kWh

# %%
#4 Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes  Sparrow and Penguin that override the fly() method

class Bird:
    def fly(self):
        print("Bird is flying")

class Sparrow(Bird):
    def fly(self):
        print("Sparrow is flying")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly")

bird = Bird()
sparrow = Sparrow()
penguin = Penguin()

bird.fly()
sparrow.fly()
penguin.fly()
# Out:
# Bird is flying
# Sparrow is flying
# Penguin cannot fly

# %%
#5 Write a program to demonstrate encapsulation by creating a class BankAccount with private attributes  balance and methods to deposit, withdraw, and check balance.

class BankAccount:
    def __init__(self, initial_balance):
        self.__balance = initial_balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
        else:
            print("Deposit amount must be positive")

    def withdraw(self, amount):
        if amount > 0 and amount <= self.__balance:
            self.__balance -= amount
        else:
            print("Invalid withdrawal amount")

    def check_balance(self):
        return self.__balance

account = BankAccount(1000)
account.deposit(500)
account.withdraw(200)
print("Current Balance:", account.check_balance())
# Out:
# Current Balance: 1300

# %%
#6  Demonstrate runtime polymorphism using a method play() in a base class Instrument. Derive classes Guitar and Piano that implement their own version of play()

class Instrument:
    def play(self):
        print("Instrument is playing a sound")

class Guitar(Instrument):
    def play(self):
        print("Guitar is playing a stringed instrument")

class Piano(Instrument):
    def play(self):
        print("Piano is playing a keyboard instrument")

guitar = Guitar()
piano = Piano()

guitar.play()
piano.play()
# Out:
# Guitar is playing a stringed instrument
# Piano is playing a keyboard instrument

# %%
#7 Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

class MathOperations:
    @staticmethod
    def add_numbers(a, b):
        return a + b

    @staticmethod
    def subtract_numbers(a, b):
        return a - b

result_add = MathOperations.add_numbers(5, 3)
result_subtract = MathOperations.subtract_numbers(10, 4)

print(f"Addition Result: {result_add}")
print(f"Subtraction Result: {result_subtract}")
# Out:
# Addition Result: 8
# Subtraction Result: 6

# %%
#8  Implement a class Person with a class method to count the total number of persons created.

class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def get_count(cls):
        return cls.count

person1 = Person("John")
person2 = Person("Jane")

print(Person.get_count())
# Out:
# 2

# %%
#9 Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

class Fraction:
    def __init__(self, numerator, denominator):
        self.numerator = numerator
        self.denominator = denominator

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

fraction = Fraction(3, 4)
print(fraction)
# Out:
# 3/4

# %%
#10  Demonstrate operator overloading by creating a class Vector and overriding the add method to add two vectors.

class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Vector(self.x + other.x, self.y + other.y)

    def __str__(self):
        return f"({self.x}, {self.y})"

    def __repr__(self):
        return f"Vector({self.x}, {self.y})"

    def __eq__(self, other):
        return self.x == other.x and self.y == other.y

    def __ne__(self, other):
        return not self == other

v1 = Vector(1, 2)
v2 = Vector(3, 4)
v3 = v1 + v2
print(v3)
# Out:
# (4, 6)

# %%
#11 Create a class Person with attributes name and age. Add a method greet() that prints "Hello, my name is {name} and I am {age} years old."

class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

    def __str__(self):
        return f"Person(name='{self.name}', age={self.age})"

person = Person("Akansha", 25)
print(person)
# Out:
# Person(name='Akansha', age=25)

# %%
#12  Implement a class Student with attributes name and grades. Create a method average_grade() to compute the average of the grades.

class Student:
    def __init__(self, name,
                 grades):
        self.name = name
        self.grades = grades

    def average_grade(self):
        return sum(self.grades) / len(self.grades)

student = Student("Akansha", [85, 90, 78, 92])
print(f"Average Grade: {student.average_grade()}")
# Out:
# Average Grade: 86.25

# %%
#13 Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

class Rectangle:
    def __init__(self):
        self.length = 0
        self.width = 0

    def set_dimensions(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

# Create a Rectangle object
rectangle = Rectangle()

# Set the dimensions of the rectangle
rectangle.set_dimensions(5, 3)

# Calculate and print the area of the rectangle
area = rectangle.area()
print("Area of the rectangle:", area)
# Out:
# Area of the rectangle: 15

# %%
#14 Create a class Employee with a method calculate_salary() that computes the salary based on hours worked and hourly rate. Create a derived class Manager that adds a bonus to the salary.

class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

employee = Employee(40, 25)
employee_salary = employee.calculate_salary()
print("Employee Salary:", employee_salary)

manager = Manager(40, 30, 500)
manager_salary = manager.calculate_salary()
print("Manager Salary:", manager_salary)
# Out:
# Employee Salary: 1000
# Manager Salary: 1700

# %%
#15  Create a class Product with attributes name, price, and quantity. Implement a method total_price() that calculates the total price of the product.

class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

product = Product("Laptop", 1000, 3)
total_cost = product.total_price()
print("Total Price of Product:", total_cost)
# Out:
# Total Price of Product: 3000

# %%
#16 Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement the sound() method.

from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        return "Moo"

class Sheep(Animal):
    def sound(self):
        return "Baa"

cow = Cow()
sheep = Sheep()

print("Cow sound:", cow.sound())
print("Sheep sound:", sheep.sound())
# Out:
# Cow sound: Moo
# Sheep sound: Baa

# %%
#17 Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the book's details.

class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

book = Book("The Kite Runner", "Khaled Hosseini", 2003)
book_info = book.get_book_info()
print(book_info)
# Out:
# Title: The Kite Runner, Author: Khaled Hosseini, Year Published: 2003

# %%
#18  Create a class House with attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

mansion = Mansion("Vasant Kunj, Delhi", 5000000, 3)
print("Address:", mansion.address)
print("Price:", mansion.price)
print("Number of Rooms:", mansion.number_of_rooms)
# Out:
# Address: Vasant Kunj, Delhi
# Price: 5000000
# Number of Rooms: 3
